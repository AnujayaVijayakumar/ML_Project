# %%
import numpy as np

# %%
d = np.load("models/mlp_gesture.npz")

# %%
print(d.files)
# Out:
# ['W1', 'b1', 'W2', 'b2', 'meta_feat_dim']

# %%
print(d["W1"].shape)
print(d["b1"].shape)
print(d["W2"].shape)
print(d["b2"].shape)
# Out:
# (870, 64)
# (1, 64)
# (64, 4)
# (1, 4)

# %%
print(d["W1"])
# Out:
# [[ 0.0123604  -0.01443238  0.02640682 ...  0.01222388 -0.05412454
#   -0.01165424]
#  [-0.01404723  0.02092178  0.00824915 ... -0.06116636  0.09273792
#   -0.02700025]
#  [ 0.01384501 -0.02566597  0.07947079 ... -0.03538688  0.01776971
#    0.05614319]
#  ...
#  [ 0.01338507  0.0475117   0.0615149  ...  0.09967551  0.06895243
#   -0.02401353]
#  [ 0.0094133  -0.07836366  0.02888684 ...  0.008265    0.059393
#   -0.08001041]
#  [ 0.01025042  0.05047941  0.0496791  ... -0.06606204  0.03683192
#    0.10219114]]

# %%
print(type(d.meta_feat_dim))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(type(d.meta_feat_dim))
#
# AttributeError: 'NpzFile' object has no attribute 'meta_feat_dim'
